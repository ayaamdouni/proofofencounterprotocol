# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3226,4562,3290,2678,2740,930,2606,2749,2852,2479,2579,2510,7747,6829,1457,
                    2720,2681,931,924,3892,4617,2058,1213,590,199,2882,1680,1113,2734,243])

plt.plot(ypoints)
plt.show()

# %%
initPoints = np.array([12759, 12823, 14337, 13167, 12098, 13228, 14491, 14999, 13200, 13573,
    12531, 12305, 13370, 12854, 15282, 14264, 17280, 15574, 12344, 13207,
    15092, 12627, 13139, 15875, 13822, 12227, 15153, 15602, 13566, 12539])

plt.plot(initPoints)
plt.show()

# %%
proofPoints = np.array([
    25918, 23161, 25307, 24109, 23564, 25166, 24147, 23485, 25742, 23550,
    23430, 24796, 25988, 24194, 24783, 23513, 24611, 23671, 23776, 25245,
    22718, 23812, 24076, 24075, 22864, 24774, 22494, 24119, 23974, 22589
])

plt.plot(proofPoints)
plt.show()

# %%
finalPoints = np.array([
    621, 631, 676, 524, 674, 618, 568, 695, 564, 503,
    523, 602, 586, 565, 621, 518, 520, 533, 641, 577,
    678, 641, 631, 680, 673, 646, 611, 541, 574, 620
])

plt.plot(finalPoints)
plt.show()
