# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3226,4562,3290,2678,2740,930,2606,2749,2852,2479,2579,2510,7747,6829,1457,
                    2720,2681,931,924,3892,4617,2058,1213,590,199,2882,1680,1113,2734,243])

plt.plot(ypoints)
plt.show()

# %%
initPoints = np.array([10527, 16531, 15330, 36932, 15845, 17469, 187406, 11964, 123894, 16842])

plt.plot(initPoints)
plt.show()

# %%
proofPoints = np.array([22693, 20759, 27764, 19130, 23568, 24646, 21489, 24896, 25638, 23937])

plt.plot(proofPoints)
plt.show()

# %%
finalPoints = np.array([599, 597, 521, 923, 756, 895, 654, 789, 646, 523])

plt.plot(finalPoints)
plt.show()
